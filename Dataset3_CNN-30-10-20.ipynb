# %% [markdown]
# # SPEAKER IDENTIFICATION
# CNN on AudioMnist - SUBset

# %%
import os
from pathlib import Path

# %matplotlib inline
import numpy as np
from sklearn import preprocessing
import tensorflow as tf
from tensorflow import keras
import matplotlib
import matplotlib.pyplot as plt
import librosa
import librosa.display
import pandas as pd

import soundfile

from tensorflow.keras.callbacks import TensorBoard

# %%
source   = "NEW_AudioMnist_SUBSET"


train_file = "AudioMNIST_train30.csv"
with open(train_file, 'r') as file:
    file_paths_train = [line.strip() for line in file.readlines()]

list_ds_train = tf.data.Dataset.from_tensor_slices(file_paths_train)

test_file = "AudioMNIST_test20.csv"
with open(test_file, 'r') as file:
    file_paths_test = [line.strip() for line in file.readlines()]

list_ds_test = tf.data.Dataset.from_tensor_slices(file_paths_test)

val_file = "AudioMNIST_val10.csv"
with open(val_file, 'r') as file:
    file_paths_val = [line.strip() for line in file.readlines()]

list_ds_val = tf.data.Dataset.from_tensor_slices(file_paths_val)

# %% [markdown]
# ## get names

# %%
def extract_speaker(file_path):
    sc = tf.strings.split(file_path, '.')[0] #[0]
    sc = tf.strings.split(sc, '_')[1]
    return sc

# %%
speaker_ds_test = list_ds_test.map(extract_speaker)
speaker_ds_val = list_ds_val.map(extract_speaker)
speaker_ds_train = list_ds_train.map(extract_speaker)

# %%
def path_speaker(file_path):
    source   = "NEW_AudioMnist_SUBSET/"
    sc =  tf.strings.split(file_path)[0]  #[0]
    return source + sc

# %%
path_ds_test = list_ds_test.map(path_speaker)
for f in path_ds_test.take(3):
    print(f.numpy())
# Out:
# b'NEW_AudioMnist_SUBSET/0_01_8.wav'
# b'NEW_AudioMnist_SUBSET/0_01_9.wav'
# b'NEW_AudioMnist_SUBSET/1_01_8.wav'

# %%
path_ds_val = list_ds_val.map(path_speaker)
for f in path_ds_val.take(3):
    print(f.numpy())
# Out:
# b'NEW_AudioMnist_SUBSET/0_01_7.wav'
# b'NEW_AudioMnist_SUBSET/1_01_7.wav'
# b'NEW_AudioMnist_SUBSET/2_01_7.wav'

# %%
path_ds_train = list_ds_train.map(path_speaker)
for f in path_ds_train.take(3):
    print(f.numpy())
# Out:
# b'NEW_AudioMnist_SUBSET/0_01_0.wav'
# b'NEW_AudioMnist_SUBSET/0_01_1.wav'
# b'NEW_AudioMnist_SUBSET/0_01_2.wav'

# %% [markdown]
# ## Encoder for audios and names

# %%
speaker_encoder = preprocessing.LabelEncoder() # create encoder
speaker_idx_test = speaker_encoder.fit_transform([bytes.decode(s.numpy()) for s in speaker_ds_test]) #fit decoded index(01)
encoded_speaker_ds_test = tf.data.Dataset.from_tensor_slices(speaker_idx_test) #dataset of encoded index
unique_speakers = len(speaker_encoder.classes_)

unique_speakers
# Out:
# 60

# %%
speaker_idx_test.shape
# Out:
# (1200,)

# %%
speaker_idx_train = speaker_encoder.fit_transform([bytes.decode(s.numpy()) for s in speaker_ds_train]) #fit decoded index(01)
encoded_speaker_ds_train = tf.data.Dataset.from_tensor_slices(speaker_idx_train) #dataset of encoded index
unique_speakers = len(speaker_encoder.classes_)

unique_speakers
# Out:
# 60

# %%
speaker_idx_train.shape
# Out:
# (1800,)

# %%
speaker_idx_val = speaker_encoder.fit_transform([bytes.decode(s.numpy()) for s in speaker_ds_val]) #fit decoded index(01)
encoded_speaker_ds_val = tf.data.Dataset.from_tensor_slices(speaker_idx_val) #dataset of encoded index
unique_speakers = len(speaker_encoder.classes_)

unique_speakers
# Out:
# 60

# %%
speaker_idx_val.shape
# Out:
# (600,)

# %%
def wav2mfcc(file_path, max_pad_len=196): #extracting the mfcc
    ''' convert wav file to mfcc matrix with truncation and padding '''
    wave, sample_rate = librosa.load(file_path, mono=True, sr=None)  # READ the wav file
    mfcc = librosa.feature.mfcc(y=wave, sr = sample_rate) #get mfcc with librosa library
    mfcc = mfcc[:, :max_pad_len] #truncate the mfcc to 196 samples
    pad_width = max_pad_len - mfcc.shape[1]  # to pad in case not enought samples 
    mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant') # pad constant (0)
    return mfcc

# %%
def extract_mfcc(file_path): # creating a tensor of -mfcc
    ''' returns 3D tensor of the mfcc coding from the wav file '''
    file_name = bytes.decode(file_path.numpy()) #decode file path as file name
    mfcc = tf.convert_to_tensor(wav2mfcc(file_name)) #create a tensor of mfcc
    mfcc = tf.expand_dims(mfcc, 2) #index 2   https://www.tensorflow.org/api_docs/python/tf/expand_dims
    return mfcc

# %%
def create_audio_ds(list_ds): #create a dataset of MFCC
    ''' creates audio dataset containing audio tensors from file list dataset '''
    batch = []
    for f in list_ds: # in the list with the paths
        print(f)
        audio = extract_mfcc(f) # extracting MFCC
        batch.append(audio)
    return tf.data.Dataset.from_tensor_slices(batch) #Dataset of MFCC

# %%
# %time audio_ds_test = create_audio_ds(path_ds_test)
# %time audio_ds_val = create_audio_ds(path_ds_val)
# %time audio_ds_train = create_audio_ds(path_ds_train) #create a dataset of MFCC
# Out:
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_01_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_01_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_02_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_02_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_03_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_03_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_04_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_04_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_05_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_05_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_06_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_06_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_07_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_07_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_08_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_08_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_09_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_09_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_10_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_10_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_11_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_11_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_12_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_12_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_13_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_13_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_14_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_14_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_15_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_15_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_16_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_16_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_17_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_17_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_18_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_18_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_19_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_19_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_20_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_20_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_21_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_21_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_22_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_22_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_23_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_23_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_24_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_24_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_25_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_25_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_26_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_26_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_27_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_27_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_28_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_28_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_29_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_29_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_30_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_30_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_31_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_31_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_32_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_32_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_33_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_33_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_34_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_34_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_34_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_34_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_34_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_34_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_34_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_34_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_34_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_34_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_34_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_34_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_34_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_34_9.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_34_8.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_34_9.wav', shape=(), dtype=string)
# ...
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_53_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_53_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_53_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_53_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_53_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_53_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_53_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_53_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_53_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_53_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_53_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_53_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_53_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_53_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_53_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_54_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_54_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_54_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_55_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_55_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_55_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_56_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_56_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_56_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_57_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_57_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_57_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_58_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_58_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_58_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_59_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_59_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_59_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/0_60_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/1_60_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/2_60_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/3_60_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/4_60_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/5_60_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/6_60_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/7_60_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/8_60_2.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_60_0.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_60_1.wav', shape=(), dtype=string)
# tf.Tensor(b'NEW_AudioMnist_SUBSET/9_60_2.wav', shape=(), dtype=string)
# Wall time: 29.7 s

# %%
# Audio (input) tensor is 3D tensor.
# 20x196 is MFCC encoding. Converting it to 3D for use in CNN layers.
for a in audio_ds_test.take(1):
    print(a.numpy().shape)
# Out:
# (20, 196, 1)

# %%
for a in audio_ds_train.take(1):
    print(a.numpy().shape)
# Out:
# (20, 196, 1)

# %%
for a in audio_ds_val.take(1):
    print(a.numpy().shape)
# Out:
# (20, 196, 1)

# %%
#Zip the input and labels to a single dataset.
labeled_ds_test = tf.data.Dataset.zip((audio_ds_test, encoded_speaker_ds_test))
labeled_ds_train = tf.data.Dataset.zip((audio_ds_train, encoded_speaker_ds_train))
labeled_ds_val = tf.data.Dataset.zip((audio_ds_val, encoded_speaker_ds_val))

# %%
input_shape = None
for audio, speaker in labeled_ds_test.take(1):
    input_shape = audio.shape
    print('input_shape', audio.shape)
    print('output_shape', speaker.shape)
# Out:
# input_shape (20, 196, 1)
# output_shape ()

# %%
# create train, validation and test datasets.

train_size = sum([1 for _ in labeled_ds_train])
val_size = sum([1 for _ in labeled_ds_val])
test_size = sum([1 for _ in labeled_ds_test])
data_size = train_size+val_size+test_size
print('all samples: {}'.format(data_size))
print('training samples: {}'.format(train_size))
print('validation samples: {}'.format(val_size))
print('test samples: {}'.format(test_size))
# Out:
# all samples: 3600
# training samples: 1800
# validation samples: 600
# test samples: 1200

# %%
# create batched datasets
batch_size = 32
train_ds = labeled_ds_train.shuffle(train_size, seed=42, reshuffle_each_iteration=False).batch(batch_size)
val_ds = labeled_ds_val.shuffle(val_size, seed=42, reshuffle_each_iteration=False).batch(batch_size)
test_ds = labeled_ds_test.shuffle(test_size, seed=42, reshuffle_each_iteration=False).batch(batch_size)

# %%
def create_model():
    
    dropout_rate = .25
    regularazation = 0.001
    
    audio_input = keras.layers.Input(shape=input_shape)
    
    conv1 = keras.layers.Conv2D(16, kernel_size=(3, 3), padding='same',
                               activation='relu', input_shape=input_shape)(audio_input)
    maxpool1 = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2)(conv1)
    batch1 = keras.layers.BatchNormalization()(maxpool1)
    
    conv2 = keras.layers.Conv2D(32, kernel_size=(3, 3), padding='same',
                               activation='relu', input_shape=input_shape)(batch1)
    maxpool2 = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2)(conv2)
    batch2 = keras.layers.BatchNormalization()(maxpool2)
    
    conv3 = keras.layers.Conv2D(64, kernel_size=(3, 3), padding='same', 
                activation='relu')(batch2)
    maxpool3 = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2)(conv3)
    batch3 = keras.layers.BatchNormalization()(maxpool3)
    
    flt = keras.layers.Flatten()(batch3)
    
    drp1 = keras.layers.Dropout(dropout_rate)(flt)
    
    dense1 = keras.layers.Dense(unique_speakers * 2, activation='relu',
                kernel_regularizer=keras.regularizers.l2(regularazation))(drp1)
    
    drp2 = keras.layers.Dropout(dropout_rate)(dense1)
    
    output = keras.layers.Dense(unique_speakers, activation='softmax', name='speaker')(drp2)
    
    model = keras.Model(inputs=audio_input, outputs=output)
    model.compile(loss=keras.losses.sparse_categorical_crossentropy,
                  optimizer=keras.optimizers.Adam(),
                  metrics=['acc', 'sparse_top_k_categorical_accuracy'])
    return model

# %%
train_model = False
model_name = 'spr_model_30-10-20.h5'
model_path = os.path.join('.', model_name)
model = None
model = create_model()
train_model = True

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20, 196, 1)]      0
#
#  conv2d (Conv2D)             (None, 20, 196, 16)       160
#
#  max_pooling2d (MaxPooling2D  (None, 10, 98, 16)       0
#  )
#
#  batch_normalization (BatchN  (None, 10, 98, 16)       64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 10, 98, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 49, 32)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 5, 49, 32)        128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 5, 49, 64)         18496
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 24, 64)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 2, 24, 64)        256
#  hNormalization)
#
#  flatten (Flatten)           (None, 3072)              0
#
#  dropout (Dropout)           (None, 3072)              0
#
#  dense (Dense)               (None, 120)               368760
#
#  dropout_1 (Dropout)         (None, 120)               0
#
#  speaker (Dense)             (None, 60)                7260
#
# =================================================================
# Total params: 399,764
# Trainable params: 399,540
# Non-trainable params: 224
# _________________________________________________________________

# %%
history = {}

tf.keras.metrics.TopKCategoricalAccuracy(
    k=1, name='top_k_categorical_accuracy', dtype=None
)
if train_model:
    root_logdir = os.path.join(os.curdir, "spr_logs")
    def get_run_dir():
        import time
        run_id = time.strftime("run%Y_%m_%d-%H_%M_%S")
        return os.path.join(root_logdir, run_id)
    run_logdir = get_run_dir()
    tensorboard_cb = keras.callbacks.TensorBoard(run_logdir, update_freq='batch')
    history = model.fit(train_ds, epochs=8, validation_data=val_ds, callbacks=[tensorboard_cb])
# Out:
# Epoch 1/8
# 57/57 [==============================] - 7s 78ms/step - loss: 4.4087 - acc: 0.0194 - sparse_top_k_categorical_accuracy: 0.0822 - val_loss: 4.3078 - val_acc: 0.0183 - val_sparse_top_k_categorical_accuracy: 0.0883
# Epoch 2/8
# 57/57 [==============================] - 4s 73ms/step - loss: 4.2866 - acc: 0.0250 - sparse_top_k_categorical_accuracy: 0.0883 - val_loss: 4.2754 - val_acc: 0.0233 - val_sparse_top_k_categorical_accuracy: 0.0983
# Epoch 3/8
# 57/57 [==============================] - 4s 71ms/step - loss: 4.2495 - acc: 0.0239 - sparse_top_k_categorical_accuracy: 0.1033 - val_loss: 4.2370 - val_acc: 0.0250 - val_sparse_top_k_categorical_accuracy: 0.1200
# Epoch 4/8
# 57/57 [==============================] - 4s 72ms/step - loss: 4.1877 - acc: 0.0317 - sparse_top_k_categorical_accuracy: 0.1139 - val_loss: 4.1789 - val_acc: 0.0367 - val_sparse_top_k_categorical_accuracy: 0.1533
# Epoch 5/8
# 57/57 [==============================] - 4s 71ms/step - loss: 4.1463 - acc: 0.0306 - sparse_top_k_categorical_accuracy: 0.1317 - val_loss: 4.1451 - val_acc: 0.0417 - val_sparse_top_k_categorical_accuracy: 0.1567
# Epoch 6/8
# 57/57 [==============================] - 4s 71ms/step - loss: 4.0994 - acc: 0.0383 - sparse_top_k_categorical_accuracy: 0.1383 - val_loss: 4.0843 - val_acc: 0.0417 - val_sparse_top_k_categorical_accuracy: 0.1917
# Epoch 7/8
# 57/57 [==============================] - 4s 75ms/step - loss: 4.0368 - acc: 0.0428 - sparse_top_k_categorical_accuracy: 0.1717 - val_loss: 3.9938 - val_acc: 0.0517 - val_sparse_top_k_categorical_accuracy: 0.2133
# Epoch 8/8
# 57/57 [==============================] - 4s 74ms/step - loss: 3.9291 - acc: 0.0561 - sparse_top_k_categorical_accuracy: 0.2094 - val_loss: 3.8308 - val_acc: 0.0967 - val_sparse_top_k_categorical_accuracy: 0.2800

# %%
plt.clf()
plt.rcParams.update(plt.rcParamsDefault)
# Access the accuracy values from the training history
T1_accuracy = history.history['acc']
T1_val_accuracy = history.history['val_acc']
T2_accuracy = history.history['sparse_top_k_categorical_accuracy']
T2_val_accuracy = history.history['val_sparse_top_k_categorical_accuracy']

# Plot the accuracy values
epochs = range(1, len(T1_accuracy) + 1)
plt.plot(epochs, T1_accuracy, 'b', label='Accuracy')
plt.plot(epochs, T2_accuracy, 'b', label='T2-Accuracy', linestyle = "--")
plt.plot(epochs, T1_val_accuracy, 'r', label='Validation Accuracy')
plt.plot(epochs, T2_val_accuracy, 'r', label='Validation T2-Accuracy', linestyle = "--")
plt.title(f'Training and Validation Accuracy (CNN-30-10-20)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend()

plt.savefig(f"AudioMNIST_Training and Validation Accuracy (CNN-30-10-20).png")

# %%
model.evaluate(test_ds)
# Out:
# 38/38 [==============================] - 1s 16ms/step - loss: 3.8540 - acc: 0.0825 - sparse_top_k_categorical_accuracy: 0.2592
# [3.854018449783325, 0.08250000327825546, 0.2591666579246521]

# %%
# Make predictions on the test dataset
y_pred = model.predict(test_ds)

# Obtain top 1 and top 2 predictions
top_2 = np.argsort(-y_pred, axis=1)[:, :2] 

# Get the actual values from the test dataset
y = np.concatenate([y for x, y in test_ds], axis=0)

# Create a DataFrame from y and top_2
data = {'Test_y': y, 'Top_2_1': top_2[:, 0], 'Top_2_2': top_2[:, 1]}
results = pd.DataFrame(data)

#results.to_excel('y_CNN_3.xlsx', sheet_name='CNN_3')
# Out:
# 38/38 [==============================] - 1s 15ms/step

# %%
# Load the results DataFrame as df
df = results
plt.rcParams['font.size'] = 20

# Calculate accuracy for matching Test_y and Top_2_1
results["acc_1"] = (df['Test_y'] == df['Top_2_1'])

# Calculate accuracy for matching Test_y and (Top_2_1 & Top_2_2)
results["acc_2"]  = ((df['Test_y'] == df['Top_2_1']) | (df['Test_y'] == df['Top_2_2']))

# Get unique values of Test_y
unique_values = df['Test_y'].unique()

mean_accuracy = results.groupby(df['Test_y'])[['acc_1', 'acc_2']].mean().reset_index()
mean_accuracy.set_index(mean_accuracy.columns[0], inplace=True)

# Get the speaker names
speakers = mean_accuracy.index

# Create bar plots
fig, axs = plt.subplots(2, 1, figsize=(15, 15))
#plt.suptitle(f"AudioMNIST (CNN-30-10-20)")

axs[0].bar(range(len(speakers)), mean_accuracy['acc_1'])
axs[0].axhline(mean_accuracy['acc_1'].mean(), color='r', linestyle='--')
axs[0].set_xlabel('Speaker')
axs[0].set_ylabel('Accuracy')
axs[0].set_title('Accuracy')
axs[0].set_xticks(range(len(speakers)))
axs[0].set_ylim([0,1])
axs[0].set_xticklabels(range(1, len(speakers) + 1), rotation=90, fontsize=12)

axs[1].bar(range(len(speakers)), mean_accuracy['acc_2'])
axs[1].axhline(mean_accuracy['acc_2'].mean(), color='r', linestyle='--')
axs[1].set_xlabel('Speaker')
axs[1].set_ylabel('Top-2 Accuracy')
axs[1].set_title('TOP-2 Accuracy')
axs[1].set_xticks(range(len(speakers)))
axs[1].set_ylim([0,1])
axs[1].set_xticklabels(range(1, len(speakers) + 1), rotation=90, fontsize=12)

#fig.suptitle(f"AudioMNIST_(TRAIN {100*train_size/data_size}%)", fontsize=26)
plt.tight_layout()


# Display the plot

plt.savefig("AudioMNIST_(CNN-30-10-20).png")

# %%
plt.rcParams['font.size'] = 12
# Create a figure and axis
fig, ax = plt.subplots()

# Create a list of the two data series for box plots
data = [mean_accuracy['acc_1'], mean_accuracy['acc_2']]

# Create the box plots
box_plot = ax.boxplot(data, labels=['Accuracy', 'Top-2 Accuracy'])

# Add labels to the box plots
ax.set_ylabel('Accuracy')
ax.set_title(f"AudioMNIST_(CNN 30-10-20)")
ax.set_ylim([-0.1, 1])

# Display the plot

plt.savefig(f"AudioMNIST_(CNN 30-10-20)_BP.png")

# %%
if train_model:
    model.save(model_name)

# %%
y_test = np.concatenate([y for x, y in test_ds], axis=0)
y_val = np.concatenate([y for x, y in val_ds], axis=0)
y_train = np.concatenate([y for x, y in train_ds], axis=0)

# Create an ExcelWriter object
writer = pd.ExcelWriter('y_data_CNN3.xlsx')

# Save y_test in a sheet named 'test'
df_test = pd.DataFrame(y_test)
df_test.to_excel(writer, sheet_name='test', index=False)

# Save y_val in a sheet named 'val'
df_val = pd.DataFrame(y_val)
df_val.to_excel(writer, sheet_name='val', index=False)

# Save y_train in a sheet named 'train'
df_train = pd.DataFrame(y_train)
df_train.to_excel(writer, sheet_name='train', index=False)

# Save and close the ExcelWriter
writer.save()
