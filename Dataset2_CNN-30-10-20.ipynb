# %% [markdown]
# # SPEAKER IDENTIFICATION
# CNN on Librispeech Subset

# %%
import os
from pathlib import Path

# %matplotlib inline
import numpy as np
from sklearn import preprocessing
import tensorflow as tf
from tensorflow import keras
import matplotlib
import matplotlib.pyplot as plt
import librosa
import librosa.display
import pandas as pd

import soundfile

from tensorflow.keras.callbacks import TensorBoard

# %%
source   = "NEW_Librispeech_SUBSET"


train_file = "Librispeech_train30.csv"
with open(train_file, 'r') as file:
    file_paths_train = [line.strip() for line in file.readlines()]

list_ds_train = tf.data.Dataset.from_tensor_slices(file_paths_train)

test_file = "Librispeech_test20.csv"
with open(test_file, 'r') as file:
    file_paths_test = [line.strip() for line in file.readlines()]

list_ds_test = tf.data.Dataset.from_tensor_slices(file_paths_test)

val_file = "Librispeech_val10.csv"
with open(val_file, 'r') as file:
    file_paths_val = [line.strip() for line in file.readlines()]

list_ds_val = tf.data.Dataset.from_tensor_slices(file_paths_val)

# %% [markdown]
# ## get names

# %%
def extract_speaker(file_path):
    sc = tf.strings.split(file_path, '.')[0] #[0]
    sc = tf.strings.split(sc, '-')[0]
    print(sc)
    return sc

# %%
speaker_ds_test = list_ds_test.map(extract_speaker)
speaker_ds_val = list_ds_val.map(extract_speaker)
speaker_ds_train = list_ds_train.map(extract_speaker)
# Out:
# Tensor("strided_slice_1:0", shape=(), dtype=string)
# Tensor("strided_slice_1:0", shape=(), dtype=string)
# Tensor("strided_slice_1:0", shape=(), dtype=string)

# %%
def path_speaker(file_path):
    source   = "NEW_Librispeech_SUBSET/"
    sc =  tf.strings.split(file_path)[0]  #[0]
    return source + sc

# %%
path_ds_test = list_ds_test.map(path_speaker)
for f in path_ds_test.take(3):
    print(f.numpy())
# Out:
# b'NEW_Librispeech_SUBSET/19-227-0042.flac'
# b'NEW_Librispeech_SUBSET/19-227-0043.flac'
# b'NEW_Librispeech_SUBSET/19-227-0044.flac'

# %%
path_ds_val = list_ds_val.map(path_speaker)
for f in path_ds_val.take(3):
    print(f.numpy())
# Out:
# b'NEW_Librispeech_SUBSET/19-227-0035.flac'
# b'NEW_Librispeech_SUBSET/19-198-0035.flac'
# b'NEW_Librispeech_SUBSET/19-227-0036.flac'

# %%
path_ds_train = list_ds_train.map(path_speaker)
for f in path_ds_train.take(3):
    print(f.numpy())
# Out:
# b'NEW_Librispeech_SUBSET/19-227-0000.flac'
# b'NEW_Librispeech_SUBSET/19-198-0000.flac'
# b'NEW_Librispeech_SUBSET/19-227-0001.flac'

# %% [markdown]
# ## Encoder for audios and names

# %%
# create one-hot vector dataset from speakers
speaker_encoder = preprocessing.LabelEncoder() # create encoder
speaker_idx_test = speaker_encoder.fit_transform([bytes.decode(s.numpy()) for s in speaker_ds_test]) #fit decoded index(01)
encoded_speaker_ds_test = tf.data.Dataset.from_tensor_slices(speaker_idx_test) #dataset of encoded index
unique_speakers = len(speaker_encoder.classes_)

unique_speakers
# Out:
# 81

# %%
speaker_idx_test
# Out:
# array([18, 18, 18, ..., 78, 78, 78], dtype=int64)

# %%
speaker_idx_train = speaker_encoder.fit_transform([bytes.decode(s.numpy()) for s in speaker_ds_train]) #fit decoded index(01)
encoded_speaker_ds_train = tf.data.Dataset.from_tensor_slices(speaker_idx_train) #dataset of encoded index
unique_speakers = len(speaker_encoder.classes_)

unique_speakers
# Out:
# 81

# %%
speaker_idx_train.shape
# Out:
# (2430,)

# %%
speaker_idx_val = speaker_encoder.fit_transform([bytes.decode(s.numpy()) for s in speaker_ds_val]) #fit decoded index(01)
encoded_speaker_ds_val = tf.data.Dataset.from_tensor_slices(speaker_idx_val) #dataset of encoded index
unique_speakers = len(speaker_encoder.classes_)

unique_speakers
# Out:
# 81

# %%
speaker_idx_val.shape
# Out:
# (810,)

# %%
def wav2mfcc(file_path, max_pad_len=196): #extracting the mfcc
    ''' convert wav file to mfcc matrix with truncation and padding '''
    wave, sample_rate = librosa.load(file_path, mono=True, sr=None)  # READ the wav file
    mfcc = librosa.feature.mfcc(y=wave, sr = sample_rate) #get mfcc with librosa library
    mfcc = mfcc[:, :max_pad_len] #truncate the mfcc to 196 samples
    pad_width = max_pad_len - mfcc.shape[1]  # to pad in case not enought samples 
    mfcc = np.pad(mfcc, pad_width=((0, 0), (0, pad_width)), mode='constant') # pad constant (0)
    return mfcc

# %%
def extract_mfcc(file_path): # creating a tensor of -mfcc
    ''' returns 3D tensor of the mfcc coding from the wav file '''
    file_name = bytes.decode(file_path.numpy()) #decode file path as file name
    mfcc = tf.convert_to_tensor(wav2mfcc(file_name)) #create a tensor of mfcc
    mfcc = tf.expand_dims(mfcc, 2) #index 2   https://www.tensorflow.org/api_docs/python/tf/expand_dims
    return mfcc

# %%
def create_audio_ds(list_ds): #create a dataset of MFCC
    ''' creates audio dataset containing audio tensors from file list dataset '''
    batch = []
    for f in list_ds: # in the list with the paths
        print(f)
        audio = extract_mfcc(f) # extracting MFCC
        batch.append(audio)
    return tf.data.Dataset.from_tensor_slices(batch) #Dataset of MFCC

# %%
# %time audio_ds_test = create_audio_ds(path_ds_test)
# %time audio_ds_val = create_audio_ds(path_ds_val)
# %time audio_ds_train = create_audio_ds(path_ds_train) #create a dataset of MFCC
# Out:
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0050.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0051.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0052.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0053.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0054.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0055.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0056.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0057.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0058.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0059.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0060.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/19-227-0061.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0053.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0054.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0055.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0056.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0057.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0058.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0059.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0060.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0061.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0062.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0063.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0064.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0065.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0066.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0067.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0068.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0069.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0070.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0071.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/26-495-0072.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-124992-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/27-123349-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0022.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0023.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0024.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0025.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0034.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0035.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0036.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0037.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0038.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0039.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/32-4137-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-121026-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-121026-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-121026-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-121026-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-121026-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0050.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0051.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0052.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0053.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/40-222-0054.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-369-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/78-368-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0034.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0034.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0035.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0035.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0036.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0036.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0037.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0037.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0038.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0038.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-9960-0039.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/83-11691-0039.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0080.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0081.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0082.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0083.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0084.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0085.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0086.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0087.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0088.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0089.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0090.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0091.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0092.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0093.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0094.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0095.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0096.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0097.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0098.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/87-121553-0099.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-219-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/89-218-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1241-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1241-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1241-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1241-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0050.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0051.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0052.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0053.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0054.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/103-1240-0055.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0034.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0035.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0036.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0037.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0038.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0039.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/118-47824-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121342-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121342-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121342-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121342-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121342-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121342-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121342-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121342-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121342-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/125-121124-0050.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126107-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-132655-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126112-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126107-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-132655-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126112-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126107-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-132655-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126112-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126107-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-132655-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126112-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126107-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-132655-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126112-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126107-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-132655-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126112-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-126107-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/150-132655-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0067.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0068.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0069.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0070.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0071.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0072.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0073.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0074.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0075.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0076.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0077.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0078.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0079.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0080.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0081.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0082.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0083.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0084.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0085.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/163-122947-0086.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122150-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122159-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122152-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122150-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122159-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122152-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122150-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122159-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122152-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122150-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122159-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122152-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122150-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122159-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122152-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122150-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122159-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122152-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122150-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/196-122152-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-126831-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-209-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-129977-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-126831-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-209-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-129977-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-126831-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-209-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-129977-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-126831-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-209-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-129977-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-126831-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-209-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-129977-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-126831-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-209-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-129977-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-126831-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/198-209-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124139-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-126784-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124140-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124139-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-126784-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124140-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124139-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-126784-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124140-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124139-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-126784-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124140-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124139-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-126784-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124140-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124139-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-126784-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124140-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-124139-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/200-126784-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-122255-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-122255-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-122255-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-122255-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-122255-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0050.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0051.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0052.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0053.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/201-127786-0054.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122442-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/211-122425-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-122538-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131533-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131532-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-122538-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131533-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131532-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-122538-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131533-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131532-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-122538-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131533-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131532-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-122538-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131533-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131532-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-122538-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131533-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131532-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-122538-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/226-131533-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-155990-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-155990-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-155990-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-155990-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-155990-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-155990-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-155990-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0050.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0051.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/233-134440-0052.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130644-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130697-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130652-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130644-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130697-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130652-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130644-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130697-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130652-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130644-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130697-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130652-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130644-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130697-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130652-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130644-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130697-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130652-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130644-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/248-130697-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142286-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0034.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0035.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0036.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0037.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0038.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0039.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/250-142276-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-27760-0020.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-145458-0020.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-127705-0020.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-12312-0020.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-27760-0021.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-145458-0021.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-127705-0021.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-12312-0021.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-27760-0022.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-127705-0022.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-27760-0023.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-127705-0023.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-27760-0024.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-127705-0024.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-27760-0025.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-127705-0025.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-27760-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-127705-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-27760-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/254-127705-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126790-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126790-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126790-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126790-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126790-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0050.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0051.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0052.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0053.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/298-126791-0054.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123504-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123523-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123516-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123504-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123523-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123516-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123504-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123523-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123516-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123504-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123523-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123516-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123504-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123523-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123516-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123504-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123523-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123516-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123504-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/302-123523-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127535-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127540-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127539-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127535-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127540-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127539-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127535-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127540-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127539-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127535-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127540-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127539-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127535-0030.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127540-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127539-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127535-0031.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127540-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127539-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127535-0032.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/307-127540-0033.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0080.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0081.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0082.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0083.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0084.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0085.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0086.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0087.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0088.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0089.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0090.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0091.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0092.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0093.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0094.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0095.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0096.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0097.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0098.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/311-124404-0099.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0046.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0047.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0048.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0049.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0050.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0051.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0052.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0053.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0054.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0055.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0056.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0057.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0058.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0059.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0060.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/322-124147-0061.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180299-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180298-0040.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180299-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180298-0041.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180299-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180298-0042.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180299-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180298-0043.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180299-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180298-0044.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180299-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180298-0045.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/374-180299-0046.flac', shape=(), dtype=string)
# ...
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279791-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279790-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279791-0010.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279790-0010.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279791-0011.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279790-0011.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279791-0012.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279790-0012.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279791-0013.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279790-0013.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279791-0014.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8312-279790-0014.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0010.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0010.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0011.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0011.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0012.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0012.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0013.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0013.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305213-0014.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8630-305212-0014.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0010.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0011.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0012.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0013.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0014.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0015.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0016.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0017.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0018.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0019.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0020.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0021.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0022.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0023.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0024.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0025.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8747-293952-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295465-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295463-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8770-295462-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0010.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0011.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0012.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0013.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0014.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0015.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0016.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0017.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0018.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0019.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0020.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0021.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0022.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0023.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0024.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0025.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8797-294123-0029.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0010.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0010.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0011.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0011.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0012.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0012.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0013.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0013.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298546-0014.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8838-298545-0014.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0000.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0001.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0002.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0003.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0004.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0005.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0006.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0007.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0008.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0009.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0010.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0011.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0012.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0013.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0014.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0015.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0016.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0017.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0018.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0019.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0020.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0021.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0022.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0023.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0024.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0025.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0026.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0027.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0028.flac', shape=(), dtype=string)
# tf.Tensor(b'NEW_Librispeech_SUBSET/8975-270782-0029.flac', shape=(), dtype=string)
# Wall time: 1min 37s

# %%
# Audio (input) tensor is 3D tensor.
# 20x196 is MFCC encoding. Converting it to 3D for use in CNN layers.
for a in audio_ds_test.take(1):
    print(a.numpy().shape)
# Out:
# (20, 196, 1)

# %%
for a in audio_ds_train.take(1):
    print(a.numpy().shape)
# Out:
# (20, 196, 1)

# %%
for a in audio_ds_val.take(1):
    print(a.numpy().shape)
# Out:
# (20, 196, 1)

# %%
#Zip the input and labels to a single dataset.
labeled_ds_test = tf.data.Dataset.zip((audio_ds_test, encoded_speaker_ds_test))
labeled_ds_train = tf.data.Dataset.zip((audio_ds_train, encoded_speaker_ds_train))
labeled_ds_val = tf.data.Dataset.zip((audio_ds_val, encoded_speaker_ds_val))

# %%
input_shape = None
for audio, speaker in labeled_ds_test.take(1):
    input_shape = audio.shape
    print('input_shape', audio.shape)
    print('output_shape', speaker.shape)
# Out:
# input_shape (20, 196, 1)
# output_shape ()

# %%
# create train, validation and test datasets.

train_size = sum([1 for _ in labeled_ds_train])
val_size = sum([1 for _ in labeled_ds_val])
test_size = sum([1 for _ in labeled_ds_test])
data_size = train_size+val_size+test_size
print('all samples: {}'.format(data_size))
print('training samples: {}'.format(train_size))
print('validation samples: {}'.format(val_size))
print('test samples: {}'.format(test_size))
# Out:
# all samples: 4860
# training samples: 2430
# validation samples: 810
# test samples: 1620

# %%
# create batched datasets
batch_size = 32
train_ds = labeled_ds_train.shuffle(train_size, seed=42, reshuffle_each_iteration=False).batch(batch_size)
val_ds = labeled_ds_val.shuffle(val_size, seed=42, reshuffle_each_iteration=False).batch(batch_size)
test_ds = labeled_ds_test.shuffle(test_size, seed=42, reshuffle_each_iteration=False).batch(batch_size)

# %%
def create_model():
    
    dropout_rate = .25
    regularazation = 0.001
    
    audio_input = keras.layers.Input(shape=input_shape)
    
    conv1 = keras.layers.Conv2D(16, kernel_size=(3, 3), padding='same',
                               activation='relu', input_shape=input_shape)(audio_input)
    maxpool1 = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2)(conv1)
    batch1 = keras.layers.BatchNormalization()(maxpool1)
    
    conv2 = keras.layers.Conv2D(32, kernel_size=(3, 3), padding='same',
                               activation='relu', input_shape=input_shape)(batch1)
    maxpool2 = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2)(conv2)
    batch2 = keras.layers.BatchNormalization()(maxpool2)
    
    conv3 = keras.layers.Conv2D(64, kernel_size=(3, 3), padding='same', 
                activation='relu')(batch2)
    maxpool3 = keras.layers.MaxPooling2D(pool_size=(2, 2), strides=2)(conv3)
    batch3 = keras.layers.BatchNormalization()(maxpool3)
    
    flt = keras.layers.Flatten()(batch3)
    
    drp1 = keras.layers.Dropout(dropout_rate)(flt)
    
    dense1 = keras.layers.Dense(unique_speakers * 2, activation='relu',
                kernel_regularizer=keras.regularizers.l2(regularazation))(drp1)
    
    drp2 = keras.layers.Dropout(dropout_rate)(dense1)
    
    output = keras.layers.Dense(unique_speakers, activation='softmax', name='speaker')(drp2)
    
    model = keras.Model(inputs=audio_input, outputs=output)
    model.compile(loss=keras.losses.sparse_categorical_crossentropy,
                  optimizer=keras.optimizers.Adam(),
                  metrics=['acc', 'sparse_top_k_categorical_accuracy'])
    return model

# %%
train_model = False
model_name = 'spr_model_2_70-10-20.h5'
model_path = os.path.join('.', model_name)
model = None
model = create_model()
train_model = True

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 20, 196, 1)]      0
#
#  conv2d (Conv2D)             (None, 20, 196, 16)       160
#
#  max_pooling2d (MaxPooling2D  (None, 10, 98, 16)       0
#  )
#
#  batch_normalization (BatchN  (None, 10, 98, 16)       64
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 10, 98, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 5, 49, 32)        0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 5, 49, 32)        128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 5, 49, 64)         18496
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 24, 64)        0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 2, 24, 64)        256
#  hNormalization)
#
#  flatten (Flatten)           (None, 3072)              0
#
#  dropout (Dropout)           (None, 3072)              0
#
#  dense (Dense)               (None, 162)               497826
#
#  dropout_1 (Dropout)         (None, 162)               0
#
#  speaker (Dense)             (None, 81)                13203
#
# =================================================================
# Total params: 534,773
# Trainable params: 534,549
# Non-trainable params: 224
# _________________________________________________________________

# %%
history = {}

tf.keras.metrics.TopKCategoricalAccuracy(
    k=1, name='top_k_categorical_accuracy', dtype=None
)
if train_model:
    root_logdir = os.path.join(os.curdir, "spr_logs")
    def get_run_dir():
        import time
        run_id = time.strftime("run%Y_%m_%d-%H_%M_%S")
        return os.path.join(root_logdir, run_id)
    run_logdir = get_run_dir()
    tensorboard_cb = keras.callbacks.TensorBoard(run_logdir, update_freq='batch')
    history = model.fit(train_ds, epochs=8, validation_data=val_ds, callbacks=[tensorboard_cb])
# Out:
# Epoch 1/8
# 76/76 [==============================] - 9s 84ms/step - loss: 4.6919 - acc: 0.0321 - sparse_top_k_categorical_accuracy: 0.1284 - val_loss: 4.8003 - val_acc: 0.0309 - val_sparse_top_k_categorical_accuracy: 0.0827
# Epoch 2/8
# 76/76 [==============================] - 6s 83ms/step - loss: 3.8042 - acc: 0.1588 - sparse_top_k_categorical_accuracy: 0.3774 - val_loss: 3.6891 - val_acc: 0.1494 - val_sparse_top_k_categorical_accuracy: 0.3889
# Epoch 3/8
# 76/76 [==============================] - 6s 77ms/step - loss: 2.4131 - acc: 0.4226 - sparse_top_k_categorical_accuracy: 0.7514 - val_loss: 2.0217 - val_acc: 0.5198 - val_sparse_top_k_categorical_accuracy: 0.8580
# Epoch 4/8
# 76/76 [==============================] - 6s 79ms/step - loss: 1.3791 - acc: 0.6918 - sparse_top_k_categorical_accuracy: 0.9300 - val_loss: 1.6319 - val_acc: 0.6247 - val_sparse_top_k_categorical_accuracy: 0.9099
# Epoch 5/8
# 76/76 [==============================] - 6s 77ms/step - loss: 0.9271 - acc: 0.8309 - sparse_top_k_categorical_accuracy: 0.9774 - val_loss: 1.0266 - val_acc: 0.7975 - val_sparse_top_k_categorical_accuracy: 0.9691
# Epoch 6/8
# 76/76 [==============================] - 6s 78ms/step - loss: 0.6965 - acc: 0.8963 - sparse_top_k_categorical_accuracy: 0.9934 - val_loss: 1.0264 - val_acc: 0.8000 - val_sparse_top_k_categorical_accuracy: 0.9654
# Epoch 7/8
# 76/76 [==============================] - 6s 77ms/step - loss: 0.5670 - acc: 0.9424 - sparse_top_k_categorical_accuracy: 0.9967 - val_loss: 0.9747 - val_acc: 0.8198 - val_sparse_top_k_categorical_accuracy: 0.9654
# Epoch 8/8
# 76/76 [==============================] - 6s 78ms/step - loss: 0.4989 - acc: 0.9593 - sparse_top_k_categorical_accuracy: 0.9996 - val_loss: 0.8459 - val_acc: 0.8531 - val_sparse_top_k_categorical_accuracy: 0.9765

# %%
plt.clf()
plt.rcParams.update(plt.rcParamsDefault)
# Access the accuracy values from the training history
T1_accuracy = history.history['acc']
T1_val_accuracy = history.history['val_acc']
T2_accuracy = history.history['sparse_top_k_categorical_accuracy']
T2_val_accuracy = history.history['val_sparse_top_k_categorical_accuracy']

# Plot the accuracy values
epochs = range(1, len(T1_accuracy) + 1)
plt.plot(epochs, T1_accuracy, 'b', label='Accuracy')
plt.plot(epochs, T2_accuracy, 'b', label='T2-Accuracy', linestyle = "--")
plt.plot(epochs, T1_val_accuracy, 'r', label='Validation Accuracy')
plt.plot(epochs, T2_val_accuracy, 'r', label='Validation T2-Accuracy', linestyle = "--")
plt.title(f'Training and Validation Accuracy (CNN-30-10-20)')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.ylim([0, 1])
plt.legend()

plt.savefig(f"Librispeech_Training and Validation Accuracy (CNN-30-10-20).png")

# %%
model.evaluate(test_ds)
# Out:
# 51/51 [==============================] - 1s 20ms/step - loss: 0.9165 - acc: 0.8296 - sparse_top_k_categorical_accuracy: 0.9753
# [0.9165246486663818, 0.8296296000480652, 0.9753086566925049]

# %%
# Make predictions on the test dataset
y_pred = model.predict(test_ds)

# Obtain top 1 and top 2 predictions
top_2 = np.argsort(-y_pred, axis=1)[:, :2] 

# Get the actual values from the test dataset
y = np.concatenate([y for x, y in test_ds], axis=0)

# Create a DataFrame from y and top_2
data = {'Test_y': y, 'Top_2_1': top_2[:, 0], 'Top_2_2': top_2[:, 1]}
results = pd.DataFrame(data)

#results.to_excel('y_CNN_3.xlsx', sheet_name='CNN_3')
# Out:
# 51/51 [==============================] - 1s 17ms/step

# %%
# Load the results DataFrame as df
df = results
plt.rcParams['font.size'] = 20

# Calculate accuracy for matching Test_y and Top_2_1
results["acc_1"] = (df['Test_y'] == df['Top_2_1'])

# Calculate accuracy for matching Test_y and (Top_2_1 & Top_2_2)
results["acc_2"]  = ((df['Test_y'] == df['Top_2_1']) | (df['Test_y'] == df['Top_2_2']))

# Get unique values of Test_y
unique_values = df['Test_y'].unique()

mean_accuracy = results.groupby(df['Test_y'])[['acc_1', 'acc_2']].mean().reset_index()
mean_accuracy.set_index(mean_accuracy.columns[0], inplace=True)

# Get the speaker names
speakers = mean_accuracy.index

# Create bar plots
fig, axs = plt.subplots(2, 1, figsize=(15, 15))
plt.suptitle(f"Librispeech (CNN-30-10-20)")

axs[0].bar(range(len(speakers)), mean_accuracy['acc_1'])
axs[0].axhline(mean_accuracy['acc_1'].mean(), color='r', linestyle='--')
axs[0].set_xlabel('Speaker')
axs[0].set_ylabel('Accuracy')
axs[0].set_title('Accuracy')
axs[0].set_xticks(range(len(speakers)))
axs[0].set_ylim([0,1])
axs[0].set_xticklabels(speakers, rotation=90, fontsize=12)

axs[1].bar(range(len(speakers)), mean_accuracy['acc_2'])
axs[1].axhline(mean_accuracy['acc_2'].mean(), color='r', linestyle='--')
axs[1].set_xlabel('Speaker')
axs[1].set_ylabel('Top-2 Accuracy')
axs[1].set_title('TOP-2 Accuracy')
axs[1].set_xticks(range(len(speakers)))
axs[1].set_ylim([0,1])
axs[1].set_xticklabels(speakers, rotation=90, fontsize=12)

#fig.suptitle(f"AudioMNIST_(TRAIN {100*train_size/data_size}%)", fontsize=26)
plt.tight_layout()


# Display the plot

plt.savefig("Librispeech_(CNN-30-10-20).png")

# %%
plt.rcParams['font.size'] = 12
# Create a figure and axis
fig, ax = plt.subplots()

# Create a list of the two data series for box plots
data = [mean_accuracy['acc_1'], mean_accuracy['acc_2']]

# Create the box plots
box_plot = ax.boxplot(data, labels=['Accuracy', 'Top-2 Accuracy'])

# Add labels to the box plots
ax.set_ylabel('Accuracy')
ax.set_title(f"Librispeech_(CNN 30-10-20)")
ax.set_ylim([0, 1.1])

# Display the plot

plt.savefig(f"Librispeech_(CNN 30-10-20)_BP.png")

# %%
if train_model:
    model.save(model_name)

# %%
y_test = np.concatenate([y for x, y in test_ds], axis=0)
y_val = np.concatenate([y for x, y in val_ds], axis=0)
y_train = np.concatenate([y for x, y in train_ds], axis=0)

# Create an ExcelWriter object
writer = pd.ExcelWriter('y_data_CNN3.xlsx')

# Save y_test in a sheet named 'test'
df_test = pd.DataFrame(y_test)
df_test.to_excel(writer, sheet_name='test', index=False)

# Save y_val in a sheet named 'val'
df_val = pd.DataFrame(y_val)
df_val.to_excel(writer, sheet_name='val', index=False)

# Save y_train in a sheet named 'train'
df_train = pd.DataFrame(y_train)
df_train.to_excel(writer, sheet_name='train', index=False)

# Save and close the ExcelWriter
writer.save()
